# %%
(* r = 0.1; a = 0.1; s = 0.1; K = 0.1; n = 0.1; q = 0.1;
A = a/K;
Q = (q*n)/r;
B = s/r; *)
A = 0.01; Q = 0.6 ; B = 0.29;
solution = NSolve[u^3 + (Q-1)u^2 + (A^2)u - (A^2) == 0, u, Reals];
H = u /. solution[[1]]
# Out:
# 0.400374

# %%
A = 0.01; Q = 0.6; B = 1.5; 
plot1 = StreamPlot[{u^2((1-u)(u^2+A^2)-Q*u*v), B(u-v)(u^2+A^2)v}, {u, -.1, 1.1}, {v, -.1, 1.1},
  Epilog -> {PointSize[Large], Point[{{0, 0}, {1, 0}, {H, H}}]},
  StreamPoints -> {{{{0.0845, 0}, Red}, Automatic}},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
B = 1.5;

plot2 = StreamPlot[{u^2((1-u)(u^2+A^2)-Q*u*v), B(u-v)(u^2+A^2)v}, {u, -.1, 1.5}, {v, -.1, 1.5},
  Epilog -> {PointSize[Large], Point[{{0, 0}, {1, 0}, {H, H}}]},
  StreamPoints -> {{{{0.0845, 0}, Red}, {{0.06, 0.03}, Blue}, Automatic}},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
B = ((H^2(1 − 2H) − A^2)/(H^2 + A^2));

plot2 = StreamPlot[{u^2((1-u)(u^2+A^2)-Q*u*v), B(u-v)(u^2+A^2)v}, {u, -.1, 1.5}, {v, -.1, 1.5},
  Epilog -> {PointSize[Large], Point[{{0, 0}, {1, 0}, {H, H}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-
