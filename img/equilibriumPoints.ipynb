# %%
plot = VectorPlot[{-x, y}, {x, −3, 3}, {y, −3, 3},
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  VectorPoints -> Coarse,
  VectorColorFunction -> None,
  VectorStyle -> Directive[Gray, Opacity[0.4]]]
# Out:
# -Graphics-

# %%
plot1 = StreamPlot[{-x, y}, {x, −3, 3}, {y, −3, 3},
  StreamScale -> None,
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  PerformanceGoal -> "Speed",
  StreamColorFunction -> None]
# Out:
# -Graphics-

# %%
p1 = Show[plot, plot1]
# Out:
# -Graphics-

# %%
plot2 = VectorPlot[{-x + y, -y}, {x, −3, 3}, {y, −3, 3},
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  VectorPoints -> Coarse,
  VectorColorFunction -> None,
  VectorStyle -> Directive[Gray, Opacity[0.4]]]
# Out:
# -Graphics-

# %%
plot3 = StreamPlot[{-x + y, -y}, {x, −3, 3}, {y, −3, 3},
  StreamScale -> None,
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  PerformanceGoal -> "Speed",
  StreamColorFunction -> None]
# Out:
# -Graphics-

# %%
p2 = Show[plot2, plot3]
# Out:
# -Graphics-

# %%
plot4 = VectorPlot[{x, y}, {x, −3, 3}, {y, −3, 3},
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  VectorPoints -> Coarse,
  VectorColorFunction -> None,
  VectorStyle -> Directive[Gray, Opacity[0.4]]]
# Out:
# -Graphics-

# %%
plot5 = StreamPlot[{x, y}, {x, −3, 3}, {y, −3, 3},
  StreamScale -> None,
  Frame -> False,
  Axes -> True,
  Ticks -> None,
  PerformanceGoal -> "Speed",
  StreamColorFunction -> None]
# Out:
# -Graphics-

# %%
p3 = Show[plot4, plot5]
# Out:
# -Graphics-

# %%
eqPo = GraphicsRow[{Labeled[p2, "Sumidero", Top], Labeled[p3, "Fuente", Top], Labeled[p1, "Silla", Top]}]
# Out:
# -Graphics-

# %%
Export["EquilibriumPoints.pdf", eqPo]
# Out:
# EquilibriumPoints.pdf
