# %%
RegionPlot3D[
 0 <= X < 1  && 0 <= Y < 1 && -2 < Z < 0,
 {X, -2, 2}, {Y, -2, 2}, {Z, -2, 2},
 Axes -> True,
 PlotStyle -> Opacity[0.9],
 Boxed -> False,
 AxesOrigin -> {0, 0, 0}
]
# Out:
# -Graphics3D-

# %%
Plot3D[x, {x, 0, Pi}, {z, 0, 1}, 
  PlotRange -> {{-2, 2}, {-2, 2}, {-2, 2}},
  AxesLabel -> {"x", "y", "z"},
  AxesOrigin -> {0, 0, 0},
  Boxed -> False]
# Out:
# -Graphics3D-

# %%
Graphics3D[{
  Opacity[0.5], 
  Texture[Graphics[{Gray, PointSize[0.01], 
     Table[Point[{i, j}], {i, 0, 10}, {j, 0, 10}]}]], 
  EdgeForm[], 
  FaceForm[Directive[White, TextureCoordinateFunction -> ({#1, #3} &)]],
  Polygon[{{0, -5, 0}, {0, 5, 0}, {0, 5, 5}, {0, -5, 5}}, 
   VertexTextureCoordinates -> {{0, 0}, {1, 0}, {1, 1}, {0, 1}}],
  Polygon[{{-5, -5, 0}, {5, -5, 0}, {5, -5, 5}, {-5, -5, 5}}, 
   VertexTextureCoordinates -> {{0, 0}, {1, 0}, {1, 1}, {0, 1}}],
  Text[Style["A₁", 20, Italic], {0.5, -4, 2}]
  },
 Boxed -> False, Axes -> True, AxesLabel -> {"x", "y", "z"}
]
# Out:
# -Graphics3D-

# %%
ε = 0.01; (* Espesor visual del plano *)

RegionPlot3D[
 Abs[c - (a + b)] < ε,
 {a, 0, 1}, {b, 0, 1}, {c, 0, 2},
 PlotStyle -> Directive[Opacity[0.5], Blue],
 AxesLabel -> {"a", "b", "c"},
 Boxed -> False,
 Mesh -> None
]
# Out:
# -Graphics3D-
