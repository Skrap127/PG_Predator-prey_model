# %%
$Version
# Out:
# 14.1.0 for Linux x86 (64-bit) (July 22, 2024)

# %%
plot = StreamPlot[{1-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{1, 0}, {-1,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
plot2 = StreamPlot[{-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
plot3 = StreamPlot[{-1-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  (*Epilog -> {PointSize[Large], Point[{{0,0}}]},*)
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
eqPo = GraphicsRow[{
   Labeled[plot3, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[plot2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[plot, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifSillaNodo.pdf", eqPo]
# Out:
# bifSillaNodo.pdf

# %%
p = StreamPlot[{-x-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{-1,0},{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
p2 = StreamPlot[{-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
p3 = StreamPlot[{x-x^2, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{1,0},{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
eqPo1 = GraphicsRow[{
   Labeled[p, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[p2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[p3, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifTranscritica.pdf", eqPo1]
# Out:
# bifTranscritica.pdf

# %%
pl = StreamPlot[{x-x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{-1,0},{0,0},{1,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
pl2 = StreamPlot[{-x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
pl3 = StreamPlot[{-x-x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
eqPo2 = GraphicsRow[{
   Labeled[pl3, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[pl2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[pl, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifPitchforkSup.pdf", eqPo2]
# Out:
# bifPitchforkSup.pdf

# %%
plo = StreamPlot[{x+x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
plo2 = StreamPlot[{+x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
plo3 = StreamPlot[{-x+x^3, -y}, {x, -3, 3}, {y, −3, 3},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{-1,0},{0,0},{1,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]

# %%
eqPo3 = GraphicsRow[{
   Labeled[plo3, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[plo2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[plo, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifPitchforkSub.pdf", eqPo3]
# Out:
# bifPitchforkSub.pdf

# %%
a=1;
b=1;
c=1;
img = StreamPlot[{x*(a-x^2-y^2)-y*(c+b*(x^2+y^2)), y*(a-x^2-y^2)+x*(c+b*(x^2+y^2))}, {x, -1.5, 1.5}, {y, −1.5, 1.5},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart",
  StreamPoints -> {{{{1.00032, 0}, Black}, Automatic}}]
# Out:
# -Graphics-

# %%
a=0;
b=1;
c=1;
img3 = StreamPlot[{x*(a-x^2-y^2)-y*(c+b*(x^2+y^2)), y*(a-x^2-y^2)+x*(c+b*(x^2+y^2))}, {x, -1.5, 1.5}, {y, −1.5, 1.5},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
a=-1;
b=1;
c=1;
img2 = StreamPlot[{x*(a-x^2-y^2)-y*(c+b*(x^2+y^2)), y*(a-x^2-y^2)+x*(c+b*(x^2+y^2))}, {x, -1.5, 1.5}, {y, −1.5, 1.5},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
eqPo4 = GraphicsRow[{
   Labeled[img2, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[img3, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[img, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifHopfSup.pdf", eqPo4]
# Out:
# bifHopfSup.pdf

# %%
a=-1;
b=1;
c=1;
imgn = StreamPlot[{x*(a+(x^2+y^2)-(x^2+y^2)^2)-y*(c+b*(x^2+y^2)), y*(a+(x^2+y^2)-(x^2+y^2)^2)+x*(c+b*(x^2+y^2))}, {x, -1, 1}, {y, −1, 1},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
a=0;
b=1;
c=1;
imgn2 = StreamPlot[{x*(a+(x^2+y^2)-(x^2+y^2)^2)-y*(c+b*(x^2+y^2)), y*(a+(x^2+y^2)-(x^2+y^2)^2)+x*(c+b*(x^2+y^2))}, {x, -1.5, 1.5}, {y, −1.5, 1.5},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
a=1;
b=1;
c=1;
imgn3 = StreamPlot[{x*(a+(x^2+y^2)-(x^2+y^2)^2)-y*(c+b*(x^2+y^2)), y*(a+(x^2+y^2)-(x^2+y^2)^2)+x*(c+b*(x^2+y^2))}, {x, -1.5, 1.5}, {y, −1.5, 1.5},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
eqPo5 = GraphicsRow[{
   Labeled[imgn, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[imgn2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[imgn3, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifHopfSub.pdf", eqPo5]

# %%
a=-.2;
imagn = StreamPlot[{a*x-y+x*y^2, x+a*y+y^3}, {x, -1, 1}, {y, −1, 1},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart",
  StreamPoints -> {{{{.65, 0}, Black}, Automatic}}
]
# Out:
# -Graphics-

# %%
a=0;
imagn2 = StreamPlot[{a*x-y+x*y^2, x+a*y+y^3}, {x, -1, 1}, {y, −1, 1},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"]
# Out:
# -Graphics-

# %%
a=.2;
imagn3 = StreamPlot[{a*x-y+x*y^2, x+a*y+y^3}, {x, -1, 1}, {y, −1, 1},
  Frame -> True,
  Epilog -> {PointSize[Medium], Point[{{0,0}}]},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"]
# Out:
# -Graphics-

# %%
eqPo6 = GraphicsRow[{
   Labeled[imagn, Style["\[Mu] < 0", "Modern Math"], Top],
   Labeled[imagn2, Style["\[Mu] = 0", "Modern Math"], Top],
   Labeled[imagn3, Style["\[Mu] > 0", "Modern Math"], Top]
   }]
# Out:
# -Graphics-

# %%
Export["bifHopfSub.pdf", eqPo6]
# Out:
# bifHopfSub.pdf
