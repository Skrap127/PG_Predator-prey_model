# %%
$Version
# Out:
# 14.1.0 for Linux x86 (64-bit) (July 22, 2024)

# %%
δ = 2;
c = 5;

h[x_] := Piecewise[{{δ*x, 0 <= x < c},{δ*c, c <= x}}]

typeI = Plot[h[x], {x, 0, 10}, PlotStyle -> {Black}, Ticks -> None,
 Epilog -> {
   {Black, PointSize[Large], Point[{0, 0}]}
 },
 PlotLabel -> "Type I functional response"]
# Out:
# -Graphics-

# %%
q = 2;
a = 3;

h[x_] := (q x)/(x + a)

typeII = Plot[{h[x], q}, {x, 0, 20}, PlotStyle -> {Black, {Dashed, Gray}}, 
 Axes -> True, Ticks -> None, 
 Epilog -> {
   {Black, PointSize[Large], Point[{0, 0}]}
 },
 PlotLabel -> "Type II Functional response"]
# Out:
# -Graphics-

# %%
q = 1;
a = 4;

h[x_] := (q x^2)/(x^2 + a^2)

typeIII =Plot[{h[x],q}, {x, 0, 15}, PlotStyle -> {Black, {Dashed, Gray}}, 
 Axes -> True, Ticks -> None, 
 Epilog -> {
   {Black, PointSize[Large], Point[{0, 0}]}
 },
 PlotLabel -> "Type III functional response"]
# Out:
# -Graphics-

# %%
q = 1;
a = 3;

h[x_] := (q x)/(x^2 + a^2)

typeIV = Plot[h[x], {x, 0, 16}, PlotStyle -> {Black}, 
 Axes -> True, Ticks -> None, 
 Epilog -> {
   {Black, PointSize[Large], Point[{0, 0}]}
 },
 PlotLabel -> "Type IV functional response"]
# Out:
# -Graphics-

# %%
P1 = Labeled[
 typeI,
 {
   "Densidad de la presa", 
   Rotate["Tasa de consumo", 90 Degree]
 },
 {Bottom, Left},
 LabelStyle -> Directive[FontFamily -> "Cambria Math"]
];
P2 = Labeled[
 typeII,
 {
   "Densidad de la presa", 
   Rotate["Tasa de consumo", 90 Degree]
 },
 {Bottom, Left},
 LabelStyle -> Directive[FontFamily -> "Cambria Math"]
];
P3 = Labeled[
 typeIII,
 {
   "Densidad de la presa", 
   Rotate["Tasa de consumo", 90 Degree]
 },
 {Bottom, Left},
 LabelStyle -> Directive[FontFamily -> "Cambria Math"]
];
P4 = Labeled[
 typeIV,
 {
   "Densidad de la presa", 
   Rotate["Tasa de consumo", 90 Degree]
 },
 {Bottom, Left},
 LabelStyle -> Directive[FontFamily -> "Cambria Math"]
];

# %%
Export["type1FunctionalResponse.pdf", P1]
Export["type2FunctionalResponse.pdf", P2]
Export["type3FunctionalResponse.pdf", P3]
Export["type4FunctionalResponse.pdf", P4]
# Out:
# type1FunctionalResponse.pdf
# type2FunctionalResponse.pdf
# type3FunctionalResponse.pdf
# type4FunctionalResponse.pdf
