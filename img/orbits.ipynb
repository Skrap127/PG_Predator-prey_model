# %%
plot1 = StreamPlot[{y-y^3, -x-y^2}, {x, -2, 0.368}, {y, −1.5, 1.5},
  Epilog -> {PointSize[Large], Point[{{0, 0}, {-1,1}, {-1,-1}}],
    Text[Style[TraditionalForm[Superscript[W, s][Subscript[x, 0]]], 12, Red], {-0.6, 1.1}],
    Text[Style[TraditionalForm[Superscript[W, u][Subscript[x, 0]]], 12, Blue], {-1.7, 1}]},
  StreamPoints -> {{{{-0.99, 0.99}, Red}, {{-0.95, 1.07}, Red}, {{-1.094, 1.034}, Blue}, {{-0.92, -0.96}, Blue}, {{-0.92, 0.97}, Blue}, Automatic}},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
Export["Heteroclinic.pdf", plot1]
# Out:
# Heteroclinic.pdf

# %%
plot2 = StreamPlot[{y, x-x^2}, {x, -0.5, 1.5}, {y, −1, 1},
  Epilog -> {PointSize[Large], Point[{{0, 0}, {1, 0}}]},
  StreamPoints -> {{{{0.03, 0}, Black}, Automatic}},
  StreamColorFunction -> None,
  PlotTheme -> "Scientific",
  StreamStyle -> Gray,
  StreamMarkers -> "PinDart"
]
# Out:
# -Graphics-

# %%
Export["Homoclinic.pdf", plot2]
# Out:
# Homoclinic.pdf
