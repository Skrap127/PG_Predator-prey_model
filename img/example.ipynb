# %%
plot = VectorPlot[{y, −Sin[x]}, {x, −2Pi, 2Pi}, {y, −5, 5},
  VectorColorFunction -> None,
  VectorScaling -> Automatic,
  VectorStyle -> Directive[Gray, Opacity[0.3]]]
# Out:
# -Graphics-

# %%
plot1 = StreamPlot[{y, −Sin[x]}, {x, −2Pi, 2Pi}, {y, −5, 5},
  StreamScale -> None,
  StreamColorFunction -> None,
  StreamPoints -> {{{{2, 0}, Green}, {{-3, -1}, Green}, Automatic}},
  StreamStyle -> Directive[Blue, Opacity[0.5]]]
# Out:
# -Graphics-

# %%
isoclines = ContourPlot[-Sin[x]==0*y, {x, −2Pi, 2Pi}, {y, −5, 5},
  ContourStyle -> Directive[Red, Opacity[0.4]]]
# Out:
# -Graphics-

# %%
example = Labeled[
  Show[plot, plot1, isoclines],
  LineLegend[{Directive[Gray, Opacity[0.3]], Green, Directive[Blue, Opacity[0.5]], Directive[Red, Opacity[0.4]]}, {"Campo vectorial", "Trayectorias", "Diagrama de fase", "Isoclinas"}],
  {Right}
]
# Out:
# Labeled[-Graphics-, LineLegend[{Directive[GrayLevel[0.5], Opacity[0.3]],
#
# >     RGBColor[0, 1, 0], Directive[RGBColor[0, 0, 1], Opacity[0.5]],
#
# >     Directive[RGBColor[1, 0, 0], Opacity[0.4]]},
#
# >    {Campo vectorial, Trayectorias, Diagrama de fase, Isoclinas}], {Right}]

# %%
Export["Example.pdf", example]

# %%
Integrate[1, {x, y, z} \[Element] ImplicitRegion[x^2+y^2<=z<=Sqrt[x^2+y^2],{x,y,z}]]
# Out:
# Pi
# --
# 6
