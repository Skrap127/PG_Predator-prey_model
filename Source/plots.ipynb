# %%
plot = VectorPlot[{y, −Sin[x]}, {x, −2π, 2π}, {y, −5, 5},
  VectorColorFunction -> None,
  VectorStyle -> Directive[Gray, Opacity[0.3]]]
# Out:
# -Graphics-

# %%
Export["vectorFieldExample.pdf", plot]
# Out:
# vectorFieldExample.pdf

# %%
plot1 = StreamPlot[{y, −Sin[x]}, {x, −2π, 2π}, {y, −5, 5},
  StreamScale -> None,
  StreamColorFunction -> None]
# Out:
# -Graphics-

# %%
Export["retratoFaseExample.pdf", plot1]
# Out:
# retratoFaseExample.pdf

# %%
isocline = ContourPlot[-Sin[x]==0*y, {x, −2π, 2π}, {y, −5, 5},
  ContourStyle -> Directive[Red, Opacity[0.5]]]
# Out:
# -Graphics-

# %%
Show[plot, plot1, isocline]
# Out:
# -Graphics-
