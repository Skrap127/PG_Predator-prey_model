# %%
plot = VectorPlot[{y, −Sin[x]}, {x, −2π, 2π}, {y, −5, 5}]
# Out:
# -Graphics-

# %%
Export["vectorFieldExample.pdf", plot]
# Out:
# vectorFieldExample.pdf

# %%
plot1 = StreamPlot[{y, −Sin[x]}, {x, −2π, 2π}, {y, −5, 5}]
# Out:
# -Graphics-

# %%
Export["retratoFaseExample.pdf", plot1]
# Out:
# retratoFaseExample.pdf

# %%
ContourPlot[- ,{x, −2π, 2π}, {y, −5, 5}, Contours -> {0}, ContourStyle -> Line[{Thick, color}]]
# Out:
# ContourPlot::plln: Limiting value xmin in {x, xmin, xmax} is not a machine-sized real number.
# ContourPlot[g[x, y] - m f[x, y], {x, xmin, xmax}, {y, ymin, ymax}, Contours -> {0},
#
# >   ContourStyle -> Line[{Thick, color}]]
